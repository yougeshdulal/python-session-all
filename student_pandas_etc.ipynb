# %%
pwd
# Out:
# 'C:\\Users\\Admin\\1pm_Ses'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Salary_Data.csv')
print(df)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Salary_Data.csv')
df.to_string()
# Out:
# "       Age  Gender    Education Level                              Job Title  Years of Experience    Salary\n0     32.0    Male         Bachelor's                      Software Engineer                  5.0   90000.0\n1     28.0  Female           Master's                           Data Analyst                  3.0   65000.0\n2     45.0    Male                PhD                         Senior Manager                 15.0  150000.0\n3     36.0  Female         Bachelor's                        Sales Associate                  7.0   60000.0\n4     52.0    Male           Master's                               Director                 20.0  200000.0\n5     29.0    Male         Bachelor's                      Marketing Analyst                  2.0   55000.0\n6     42.0  Female           Master's                        Product Manager                 12.0  120000.0\n7     31.0    Male         Bachelor's                          Sales Manager                  4.0   80000.0\n8     26.0  Female         Bachelor's                  Marketing Coordinator                  1.0   45000.0\n9     38.0    Male                PhD                       Senior Scientist                 10.0  110000.0\n10    29.0    Male           Master's                     Software Developer                  3.0   75000.0\n11    48.0  Female         Bachelor's                             HR Manager                 18.0  140000.0\n12    35.0    Male         Bachelor's                      Financial Analyst                  6.0   65000.0\n13    40.0  Female           Master's                        Project Manager                 14.0  130000.0\n14    27.0    Male         Bachelor's                   Customer Service Rep                  2.0   40000.0\n15    44.0    Male         Bachelor's                     Operations Manager                 16.0  125000.0\n16    33.0  Female           Master's                      Marketing Manager                  7.0   90000.0\n17    39.0    Male                PhD                        Senior Engineer                 12.0  115000.0\n18    25.0  Female         Bachelor's                       Data Entry Clerk                  0.0   35000.0\n19    51.0    Male         Bachelor's                         Sales Director                 22.0  180000.0\n20    34.0  Female           Master's                       Business Analyst                  5.0   80000.0\n21    47.0    Male           Master's                       VP of Operations                 19.0  190000.0\n22    30.0    Male         Bachelor's                             IT Support                  2.0   50000.0\n23    36.0  Female         Bachelor's                              Recruiter                  9.0   60000.0\n24    41.0    Male           Master's                      Financial Manager                 13.0  140000.0\n25    28.0  Female         Bachelor's                Social Media Specialist                  3.0   45000.0\n26    37.0  Female           Master's                       Software Manager                 11.0  110000.0\n27    24.0    Male         Bachelor's                       Junior Developer                  1.0   40000.0\n28    43.0  Female                PhD                      Senior Consultant                 15.0  140000.0\n29    33.0    Male           Master's                       Product Designer                  6.0   90000.0\n30    50.0    Male         Bachelor's                                    CEO                 25.0  250000.0\n31    31.0  Female         Bachelor's                             Accountant                  4.0   55000.0\n32    29.0    Male           Master's                         Data Scientist                  3.0   75000.0\n33    39.0  Female         Bachelor's                   Marketing Specialist                 10.0   65000.0\n34    46.0    Male                PhD                         Senior Manager                 20.0  170000.0\n35    27.0    Male         Bachelor's                       Technical Write ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df[0]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
df.loc[0]
# Out:
# Age                                 32.0
# Gender                              Male
# Education Level               Bachelor's
# Job Title              Software Engineer
# Years of Experience                  5.0
# Salary                           90000.0
# Name: 0, dtype: object

# %%
df.loc[3]
# Out:
# Age                               36.0
# Gender                          Female
# Education Level             Bachelor's
# Job Title              Sales Associate
# Years of Experience                7.0
# Salary                         60000.0
# Name: 3, dtype: object

# %%
df.loc[3:10]
# Out:
#      Age  Gender Education Level              Job Title  Years of Experience  \
# 3   36.0  Female      Bachelor's        Sales Associate                  7.0
# 4   52.0    Male        Master's               Director                 20.0
# 5   29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6   42.0  Female        Master's        Product Manager                 12.0
# 7   31.0    Male      Bachelor's          Sales Manager                  4.0
# 8   26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9   38.0    Male             PhD       Senior Scientist                 10.0
# 10  29.0    Male        Master's     Software Developer                  3.0
#
#       Salary
# 3    60000.0
# 4   200000.0
# 5    55000.0
# 6   120000.0
# 7    80000.0
# 8    45000.0
# 9   110000.0
# 10   75000.0

# %%
df.loc[3::500]
# Out:
#        Age  Gender    Education Level                  Job Title  \
# 3     36.0  Female         Bachelor's            Sales Associate
# 503   27.0    Male                PhD             Data Scientist
# 1003  26.0    Male         Bachelor's               Data Analyst
# 1503  49.0    Male                PhD  Software Engineer Manager
# 2003  33.0  Female  Bachelor's Degree        Full Stack Engineer
# 2503  55.0    Male  Bachelor's Degree    Senior Project Engineer
# 3003  30.0  Female    Master's Degree        Full Stack Engineer
# 3503  31.0    Male        High School       Junior HR Generalist
# 4003  34.0  Female  Bachelor's Degree    Human Resources Manager
# 4503  28.0  Female  Bachelor's Degree  Junior Software Developer
# 5003  28.0    Male  Bachelor's Degree  Digital Marketing Manager
# 5503  31.0    Male  Bachelor's Degree            Project Manager
# 6003  24.0  Female        High School               Receptionist
# 6503  50.0  Female    Master's Degree  Content Marketing Manager
#
#       Years of Experience    Salary
# 3                     7.0   60000.0
# 503                   2.0  115000.0
# 1003                  3.0  120000.0
# 1503                 15.0  185000.0
# 2003                  7.0  130000.0
# 2503                 28.0  193964.0
# 3003                  6.0  110707.0
# 3503                  2.0   35000.0
# 4003                  6.0   75000.0
# 4503                  2.0   37000.0
# 5003                  4.0   80000.0
# 5503                  6.0  100000.0
# 6003                  0.0   25000.0
# 6503                 19.0  190000.0

# %%
df.Gender
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4         Male
#          ...
# 6699    Female
# 6700      Male
# 6701    Female
# 6702      Male
# 6703    Female
# Name: Gender, Length: 6704, dtype: object

# %%
df['Gender']
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4         Male
#          ...
# 6699    Female
# 6700      Male
# 6701    Female
# 6702      Male
# 6703    Female
# Name: Gender, Length: 6704, dtype: object

# %%
df.index_col = "Gender"

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 6 columns]

# %%
plt.plot(df['Age'])
